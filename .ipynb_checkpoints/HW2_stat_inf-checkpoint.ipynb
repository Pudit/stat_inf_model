# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from plotnine import *
import seaborn as sns

# %%
# check path and read file csv
import os 
print(os.getcwd())
path = 'Auto.csv'
df = pd.read_csv(path)
# Out:
# /Users/pudit/stat_inf_model

# %%
# check null 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
# mpg             397 non-null float64
# cylinders       397 non-null int64
# displacement    397 non-null float64
# horsepower      397 non-null object
# weight          397 non-null int64
# acceleration    397 non-null float64
# year            397 non-null int64
# origin          397 non-null int64
# name            397 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
df.groupby(['horsepower']).size()
# Out:
# horsepower
# 100    17
# 102     1
# 103     1
# 105    12
# 107     1
# 108     1
# 110    18
# 112     3
# 113     1
# 115     5
# 116     1
# 120     4
# 122     1
# 125     3
# 129     2
# 130     5
# 132     1
# 133     1
# 135     1
# 137     1
# 138     1
# 139     2
# 140     7
# 142     1
# 145     7
# 148     1
# 149     1
# 150    22
# 152     1
# 153     2
#        ..
# 69      3
# 70     12
# 71      5
# 72      6
# 74      3
# 75     14
# 76      4
# 77      1
# 78      6
# 79      2
# 80      7
# 81      2
# 82      1
# 83      4
# 84      6
# 85      9
# 86      5
# 87      2
# 88     19
# 89      1
# 90     20
# 91      1
# 92      6
# 93      1
# 94      1
# 95     14
# 96      3
# 97      9
# 98      2
# ?       5
# Length: 94, dtype: int64

# %%
#change type horsepower and drop ?
df = df[df['horsepower'] != '?']
df[['horsepower']] = pd.to_numeric(df['horsepower'])

# %%
# see data's detail 
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
# sns.pairplot(df)
sns.pairplot(df, hue="name")

# %%
# correlation 
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# year              0.290316  1.000000  0.181528
# origin            0.212746  0.181528  1.000000

# %%
model = smf.ols(formula = 'mpg ~ cylinders + displacement + horsepower + weight + acceleration+ \
        year + origin ',data = df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Wed, 20 Feb 2019   Prob (F-statistic):          2.04e-139
# Time:                        00:49:19   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# Df Residuals:                     384   BIC:                             2095.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -17.2184      4.644     -3.707      0.000     -26.350      -8.087
# cylinders       -0.4934      0.323     -1.526      0.128      -1.129       0.142
# displacement     0.0199      0.008      2.647      0.008       0.005       0.035
# horsepower      -0.0170      0.014     -1.230      0.220      -0.044       0.010
# weight          -0.0065      0.001     -9.929      0.000      -0.008      -0.005
# acceleration     0.0806      0.099      0.815      0.415      -0.114       0.275
# year             0.7508      0.051     14.729      0.000       0.651       0.851
# origin           1.4261      0.278      5.127      0.000       0.879       1.973
# ==============================================================================
# Omnibus:                       31.906   Durbin-Watson:                   1.309
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.100
# Skew:                           0.529   Prob(JB):                     2.95e-12
# Kurtosis:                       4.460   Cond. No.                     8.59e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.59e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x = ['cylinders', 'displacement', 'weight','acceleration', 'year', 'origin']

# %%
# log(x)
dflog = df[['mpg']+x]
dflog[x] = np.log(dflog[x])
modelog = smf.ols(formula = 'mpg ~ cylinders+ displacement+ weight+ acceleration+ \
        year+ origin ',data = dflog).fit()
print(modelog.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     337.6
# Date:                Wed, 20 Feb 2019   Prob (F-statistic):          5.87e-150
# Time:                        00:49:22   Log-Likelihood:                -1001.7
# No. Observations:                 392   AIC:                             2017.
# Df Residuals:                     385   BIC:                             2045.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -80.6285     17.641     -4.571      0.000    -115.313     -45.944
# cylinders        1.4934      1.699      0.879      0.380      -1.848       4.835
# displacement    -1.0393      1.576     -0.659      0.510      -4.138       2.059
# weight         -18.6839      1.799    -10.383      0.000     -22.222     -15.146
# acceleration     0.3333      1.109      0.300      0.764      -1.848       2.515
# year            58.7365      3.540     16.594      0.000      51.777      65.696
# origin           1.3100      0.517      2.534      0.012       0.294       2.326
# ==============================================================================
# Omnibus:                       48.618   Durbin-Watson:                   1.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              106.536
# Skew:                           0.658   Prob(JB):                     7.35e-24
# Kurtosis:                       5.188   Cond. No.                     1.24e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/pudit/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3381: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
# sqrt(x)
dfsq = df[['mpg']+x]
dfsq[x] = np.sqrt(dfsq[x])
modelsq = smf.ols(formula = 'mpg ~ cylinders+ displacement+ weight+ acceleration+ \
        year+ origin ',data = dfsq).fit()
print(modelsq.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     315.7
# Date:                Wed, 20 Feb 2019   Prob (F-statistic):          2.80e-145
# Time:                        00:49:22   Log-Likelihood:                -1012.6
# No. Observations:                 392   AIC:                             2039.
# Df Residuals:                     385   BIC:                             2067.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -61.1436      8.067     -7.579      0.000     -77.005     -45.283
# cylinders       -0.0846      1.547     -0.055      0.956      -3.126       2.957
# displacement     0.1614      0.230      0.703      0.482      -0.290       0.613
# weight          -0.7334      0.066    -11.114      0.000      -0.863      -0.604
# acceleration     0.6593      0.598      1.102      0.271      -0.517       1.835
# year            13.3250      0.838     15.894      0.000      11.677      14.973
# origin           2.8957      0.759      3.813      0.000       1.403       4.389
# ==============================================================================
# Omnibus:                       39.805   Durbin-Watson:                   1.294
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.922
# Skew:                           0.591   Prob(JB):                     3.26e-17
# Kurtosis:                       4.803   Cond. No.                     2.84e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# x^2
df2 = df[['mpg']+x]
df2[x] = np.power(df2[x],2)
model2 = smf.ols(formula = 'mpg ~ cylinders+ displacement+ weight+ acceleration+ \
        year+ origin ',data = df2).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     253.2
# Date:                Wed, 20 Feb 2019   Prob (F-statistic):          2.80e-130
# Time:                        00:49:25   Log-Likelihood:                -1047.9
# No. Observations:                 392   AIC:                             2110.
# Df Residuals:                     385   BIC:                             2138.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.6644      2.233      0.298      0.766      -3.725       5.054
# cylinders       -0.0848      0.025     -3.428      0.001      -0.133      -0.036
# displacement   5.12e-05   1.15e-05      4.461      0.000    2.86e-05    7.38e-05
# weight       -9.516e-07   8.68e-08    -10.961      0.000   -1.12e-06   -7.81e-07
# acceleration     0.0071      0.002      2.869      0.004       0.002       0.012
# year             0.0050      0.000     14.484      0.000       0.004       0.006
# origin           0.4034      0.068      5.944      0.000       0.270       0.537
# ==============================================================================
# Omnibus:                       20.588   Durbin-Watson:                   1.317
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.573
# Skew:                           0.419   Prob(JB):                     6.24e-07
# Kurtosis:                       4.023   Cond. No.                     1.38e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
